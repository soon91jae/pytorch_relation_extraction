# %%
import matplotlib.cm as cm
from matplotlib.colors import Normalize
import matplotlib.pyplot as plt
cmap = cm.autumn
norm = Normalize(vmin=-20, vmax=10)

# %%
colormap = plt.cm.tab20c.colors   # Qualitative colormap

# %%
list(colormap)
# Out:
# [(0.19215686274509805, 0.5098039215686274, 0.7411764705882353),
#  (0.4196078431372549, 0.6823529411764706, 0.8392156862745098),
#  (0.6196078431372549, 0.792156862745098, 0.8823529411764706),
#  (0.7764705882352941, 0.8588235294117647, 0.9372549019607843),
#  (0.9019607843137255, 0.3333333333333333, 0.050980392156862744),
#  (0.9921568627450981, 0.5529411764705883, 0.23529411764705882),
#  (0.9921568627450981, 0.6823529411764706, 0.4196078431372549),
#  (0.9921568627450981, 0.8156862745098039, 0.6352941176470588),
#  (0.19215686274509805, 0.6392156862745098, 0.32941176470588235),
#  (0.4549019607843137, 0.7686274509803922, 0.4627450980392157),
#  (0.6313725490196078, 0.8509803921568627, 0.6078431372549019),
#  (0.7803921568627451, 0.9137254901960784, 0.7529411764705882),
#  (0.4588235294117647, 0.4196078431372549, 0.6941176470588235),
#  (0.6196078431372549, 0.6039215686274509, 0.7843137254901961),
#  (0.7372549019607844, 0.7411764705882353, 0.8627450980392157),
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook
import numpy as np
import mplcursors
np.random.seed(42)

fig, ax = plt.subplots()
ax.scatter(*np.random.random((2,40)),url = '1', label='asdfddddddddddddddddddddddddddddddddddddddddddddd')
ax.set_title("Mouse over a point")
ax.legend()
mplcursors.cursor()
plt.show()
help(mplcursors.cursor)
# Out:
# <img src="data:image/png;base64,..." width="640">
# Help on function cursor in module mplcursors._mplcursors:
#
# cursor(artists_or_axes=None, **kwargs)
#     Create a :class:`Cursor` for a list of artists or axes.
#
#     Parameters
#     ----------
#
#     artists_or_axes : Optional[List[Union[Artist, Axes]]]
#         All artists in the list and all artists on any of the axes passed in
#         the list are selectable by the constructed :class:`Cursor`.  Defaults
#         to all artists on any of the figures that :mod:`pyplot` is tracking.
#
#     **kwargs
#         Keyword arguments are passed to the :class:`Cursor` constructor.

# %%
from matplotlib import pyplot as plt
import mplcursors
from pandas import DataFrame


df = DataFrame(
    [("Alice", 163, 54),
     ("Bob", 174, 67),
     ("Charlie", 177, 73),
     ("Diane", 168, 57)],
    columns=["name", "height", "weight"])

df.plot.scatter("height", "weight")
mplcursors.cursor().connect(
    "add", lambda sel: sel.annotation.set_text(df["name"][sel.target.index]))
plt.show()

# test: skip
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df = DataFrame(dict(x=[1.0,2.0,3.,4.], y=[1.,2.,3.,4.], label=['1','2','1','2'], sent = ['one','two','three','four']))
groups = df.groupby('label')
colormap = plt.cm.tab20c.colors 
fig, ax = plt.subplots(figsize=(9, 9))
i = 0
sent_dict = {'[3. 3.]': "three"}
for name, group in groups:
    #df.plot.scatter(group.x, group.y, marker='o', linestyle='', color = colormap[i], ms=12, label=name, markersize = 2)
    ax.plot(group.x, group.y, marker='o', linestyle='', color = colormap[i], ms=12, label=name, markersize = 2)
    i += 1
ax.legend()
mplcursors.cursor().connect(
    "add", lambda sel: sel.annotation.set_text(sent_dict[str(sel.target)]))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="900">
# /home/nlp2017/.local/lib/python3.5/site-packages/matplotlib/cbook/__init__.py:2446: UserWarning: Saw kwargs ['ms', 'markersize'] which are all aliases for 'markersize'.  Kept value from 'markersize'
#   seen=seen, canon=canonical, used=seen[-1]))

# %%
df.sent[1]
